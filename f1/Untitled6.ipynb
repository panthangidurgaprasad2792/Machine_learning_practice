# %% [markdown]
# <a href="https://colab.research.google.com/github/panthangidurgaprasad2792/Machine_learning_practice/blob/main/f1/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
